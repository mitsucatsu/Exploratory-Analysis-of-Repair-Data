# %%
import pandas as pd
repair = pd.read_csv('https://raw.githubusercontent.com/cogxen/datasets/main/for-laboratory/exploring-data-with-python/repair.csv')

# %%
repair.head()
# Out:
#   country     product_category  ... repair_status  year_repaired
# 0     gbr  aircon/dehumidifier  ...   end of life           2019
# 1     nld               kettle  ...         fixed           2019
# 2     swe               mobile  ...    repairable           2018
# 3     ita     desktop computer  ...         fixed           2021
# 4     bel           power tool  ...   end of life           2019
#
# [5 rows x 7 columns]

# %%
repair.dtypes
# Out:
# country                 object
# product_category        object
# brand                   object
# year_of_manufacture    float64
# product_age            float64
# repair_status           object
# year_repaired            int64
# dtype: object

# %% [markdown]
# ## Create a list of countries

# %%
countries = repair['country'].head().tolist()

# Show output
countries
# Out:
# ['gbr', 'nld', 'swe', 'ita', 'bel']

# %%
top_three_countries = { 'nld' : 12, 'gbr': 5, 'deu': 2}

# Show output
top_three_countries
# Out:
# {'nld': 12, 'gbr': 5, 'deu': 2}

# %%
repair['country'].value_counts()
# Out:
# country
# nld    21423
# gbr    18576
# deu     7427
# bel     5008
# can     1955
# ita     1440
# usa     1388
# fra     1177
# nor     1024
# arg      617
# esp      531
# swe      509
# aus      308
# hkg      174
# irl      156
# tun       98
# isl       91
# aut       69
# jey       56
# nzl       54
# ben        9
# twn        3
# che        1
# Name: count, dtype: int64

# %%
repair['country'].value_counts(normalize=True).sort_values(ascending=False) * 100
# Out:
# country
# nld    34.500918
# gbr    29.915934
# deu    11.960898
# bel     8.065191
# can     3.148452
# ita     2.319065
# usa     2.235321
# fra     1.895513
# nor     1.649113
# arg     0.993655
# esp     0.855155
# swe     0.819725
# aus     0.496022
# hkg     0.280220
# irl     0.251232
# tun     0.157825
# isl     0.146552
# aut     0.111122
# jey     0.090186
# nzl     0.086965
# ben     0.014494
# twn     0.004831
# che     0.001610
# Name: proportion, dtype: float64

# %%
earliest_year_repaired = repair['year_repaired'].min()

# Show output
earliest_year_repaired
# Out:
# 1999

# %%
unique_countries_count = repair['country'].nunique()

# Show output
unique_countries_count
# Out:
# 23
